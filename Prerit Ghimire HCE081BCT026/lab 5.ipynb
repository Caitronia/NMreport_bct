# %% [markdown]
# ### 1.Curve Fitting: y=ax+b (Straight Line)

# %%
import numpy as np

x = np.array([8, 2, 3, 8, 5])
y = np.array([2, 5, 7, 10, 12])

n = len(x)

a = (n*np.sum(x*y) - np.sum(x)*np.sum(y)) / (n*np.sum(x*x) - (np.sum(x))**2)
b = (np.sum(y) - a*np.sum(x))/n

print("Equation of best fit:")
print(f"y = {a:.4f}x + {b:.4f}")
# Out:
# Equation of best fit:
# y = -0.0065x + 7.2338

# %% [markdown]
# ### 2.Curve Fitting: y=a+bx

# %%
import numpy as np
x = np.array([1, 3, 6, 45, 5])
y = np.array([2, 5, 7, 10, 12])
n = len(x)
a = (n*np.sum(x*y) - np.sum(x)*np.sum(y)) / (n*np.sum(x*x) - (np.sum(x))**2)
b = (np.sum(y) - a*np.sum(x))/n
print("Equation of best fit:")
print(f"y = {a:.4f}x + {b:.4f}")
# Out:
# Equation of best fit:
# y = 0.0996x + 6.0052

# %% [markdown]
# ### 3.Curve Fitting: y=ab^x

# %%
import numpy as np
x = np.array([1,0,8,8,7])
y = np.array([2,4,8,16,32])
Y = np.log10(y)
n = len(x)
B = (n*np.sum(x*Y)-np.sum(x)*np.sum(Y))/(n*np.sum(x*x)-(np.sum(x))**2)
A = (np.sum(Y)-B*np.sum(x))/n
a = 10**A
b = 10**B
print(f"y = {a:.4f}({b:.4f})^x")
# Out:
# y = 2.7728(1.2470)^x

# %% [markdown]
# ### 4.Lagrange Interpolation

# %%
def lagrange(x, y, xp):
    n = len(x)
    yp = 0

    for i in range(n):
        p = 1

        for j in range(n):
            if i != j:
                p *= (xp - x[j])/(x[i]-x[j])

        yp += p*y[i]

    return yp
x = [1,2,3]
y = [1,8,27]

xp = 5

print("Interpolated value =", lagrange(x,y,xp))
# Out:
# Interpolated value = 101.0

# %% [markdown]
# ### 5.Simpson's 1/3 Rule

# %%
def f(x):
    return x**2

a = 2
b = 10
n = 4

h = (b-a)/n

s = f(a)+f(b)

for i in range(1,n):
    if i%2==0:
        s += 2*f(a+i*h)
    else:
        s += 4*f(a+i*h)

ans = h*s/3

print("Integral =", ans)
# Out:
# Integral = 330.6666666666667

# %% [markdown]
# ### 6.Weddle's Rule

# %%
def f(x):
    return x**2

a = 4
b = 6

h = (b-a)/6

ans = (3*h/10)*(f(a)+5*f(a+h)+f(a+2*h)+6*f(a+3*h)+f(a+4*h)+5*f(a+5*h)+f(b))

print("Integral =", ans)
# Out:
# Integral = 50.666666666666664

# %% [markdown]
# ### 7.Composite Trapezoidal Rule

# %%
def f(x):
    return x**2

a = 0
b = 9
n = 4

h = (b-a)/n

s = f(a)+f(b)

for i in range(1,n):
    s += 2*f(a+i*h)

ans = h*s/2

print("Integral =", ans)
# Out:
# Integral = 250.59375
